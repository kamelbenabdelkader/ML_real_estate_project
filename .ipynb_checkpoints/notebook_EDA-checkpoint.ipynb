# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')


# sklearn
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer

# scipy
import scipy.stats as scs
from scipy.stats import norm
# for Box-Cox Transformation
from scipy import stats

# for min_max scaling
from mlxtend.preprocessing import minmax_scaling

import math

# %%
dataset = pd.read_csv("DATA/data.csv", sep=',')
dataset
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %% [markdown]
# ## Analyse bivariés

# %%
# informations dataset (numbers of rows, columns)
dataset.shape
# Out:
# (16512, 11)

# %%
# check Dtype
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16512 entries, 0 to 16511
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          16512 non-null  int64
#  1   longitude           16512 non-null  float64
#  2   latitude            16512 non-null  float64
#  3   housing_median_age  16512 non-null  float64
#  4   total_rooms         16512 non-null  float64
#  5   total_bedrooms      16336 non-null  float64
#  6   population          16512 non-null  float64
#  7   households          16512 non-null  float64
#  8   median_income       16512 non-null  float64
#  9   median_house_value  16512 non-null  float64
#  10  ocean_proximity     16512 non-null  object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 1.4+ MB

# %%
#Fonction pour regarder mes valeurs manquantes
def missing_zero_values_table(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
        mz_table['Total Zero Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
        mz_table['% Total Zero Missing Values'] = 100 * mz_table['Total Zero Missing Values'] / len(df)
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
        return mz_table

# %%
missing_zero_values_table(dataset)
# Out:
# Your selected dataframe has 11 columns and 16512 Rows.
# There are 1 columns that have missing values.
#                 Zero Values  Missing Values  % of Total Values  \
# total_bedrooms            0             176                1.1
#
#                 Total Zero Missing Values  % Total Zero Missing Values  \
# total_bedrooms                        176                          1.1
#
#                Data Type
# total_bedrooms   float64

# %% [markdown]
# Nous avons uniquement des valeurs manquantes sur total_bedrooms.
#
# 176 lignes qui répresentent 1,1 % de notre dataset.
#
# Il n' y pas de valeur 0 non plus dans notre dataset.
#
# Au vue du pourcentage je pourrais supprimer les données manquantes , ou si la feature est trop significatif envisager une imputation.

# %%
# check for zeros in all columns 
dataset[dataset == 0].count()
# Out:
# Unnamed: 0            1
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
# max & min values on total_bedrooms
print(dataset['total_bedrooms'].max())
print(dataset['total_bedrooms'].min())
# Out:
# 6445.0
# 2.0

# %%
# Fonction qui permet de tester si une cle est fiable #

def testerCle(df, colonnes):
    """Fonction qui prend en arguments un dataframe et les colonnes qui composent la clé primaire à tester."""

    # On compare la taille du dataframe avant et après dédoublonnage 
    if df.size == df.drop_duplicates(colonnes).size :
        print("La clé n'est pas présente plusieurs fois dans le dataframe.")
        print("Elle peut donc être utilisée comme clé primaire.".format(colonnes))
    else :
        print("La clé est présente plusieurs fois dans le dataframe.")
        print("Elle ne peut donc pas être utilisée comme clé primaire.".format(colonnes))
    
    # On renvoie également le comptage
    print("Le dataframe est de la forme : " + str(df.shape) + " (lignes, colonnes)")

# %%
testerCle(dataset,['Unnamed: 0'])
# Out:
# La clé n'est pas présente plusieurs fois dans le dataframe.
# Elle peut donc être utilisée comme clé primaire.
# Le dataframe est de la forme : (16512, 11) (lignes, colonnes)

# %% [markdown]
# Je supprime la colonne unnamed , en effet la colonne Unnamed semble n'être q'une identification muette sans corrélation
#
# Je vais me baser sur l'index.

# %%
df_dataset = dataset
df_dataset.drop('Unnamed: 0', inplace = True , axis = 1)
df_dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.84     36.77                 6.0       1853.0           473.0
# 1        -117.80     33.68                 8.0       2032.0           349.0
# 2        -120.19     36.60                25.0        875.0           214.0
# 3        -118.32     34.10                31.0        622.0           229.0
# 4        -121.23     37.79                21.0       1922.0           373.0
# ...          ...       ...                 ...          ...             ...
# 16507    -121.90     39.59                20.0       1465.0           278.0
# 16508    -122.25     38.11                49.0       2365.0           504.0
# 16509    -121.22     38.92                19.0       2531.0           461.0
# 16510    -118.14     34.16                39.0       2776.0           840.0
# 16511    -124.13     40.80                31.0       2152.0           462.0
#
# ...

# %% [markdown]
# ## Nettoyage des données

# %% [markdown]
# Au vue du temps allouer pour ce projet , je decide de faire de l'imputation de mes valeurs manquantes dans total_bedrooms.
#
# Même si cela représente que 1% de mes données , je vais comparer les différentes méthodes d'imputation et choisir celle qui me semble la meilleure.
#
# Cela me permet de m'entrainer sur l'imputation

# %% [markdown]
# ### Imputation des valeurs manquantes

# %%
df_dataset['total_bedrooms'].isnull().sum()
# Out:
# 176

# %%
valeur_manquantes= df_dataset.loc[np.isnan(dataset['total_bedrooms']),'total_bedrooms']
valeur_manquantes
# Out:
# 33      NaN
# 171     NaN
# 178     NaN
# 179     NaN
# 259     NaN
#          ..
# 16002   NaN
# 16089   NaN
# 16214   NaN
# 16228   NaN
# 16323   NaN
# Name: total_bedrooms, Length: 176, dtype: float64

# %% [markdown]
# #### Imputation moyenne

# %%
# Mean Imputation

df_mean = df_dataset.copy()
mean_imputer = SimpleImputer(strategy='mean')
df_mean['total_bedrooms'] = mean_imputer.fit_transform(df_mean['total_bedrooms'].values.reshape(-1,1))

# %%
# Scatter plot
fig = plt.Figure()
null_values = df_dataset['total_bedrooms'].isnull()
fig = df_mean.plot(x='total_rooms', y='total_bedrooms', kind='scatter', c=null_values, cmap='winter', title='Mean Imputation', colorbar=False)

# %% [markdown]
# #### Imputation modale

# %%
# Mode Imputation

df_mode = df_dataset.copy()
mode_imputer = SimpleImputer(strategy='most_frequent')
df_mode['total_bedrooms'] = mode_imputer.fit_transform(df_mode['total_bedrooms'].values.reshape(-1,1))

# %%
# Scatter plot

fig = plt.Figure()
null_values = df_dataset['total_bedrooms'].isnull()
fig = df_mode.plot(x='total_rooms', y='total_bedrooms', kind='scatter', c=null_values, cmap='winter', title='Mode Imputation', colorbar=False)

# %% [markdown]
# #### Imputation K-plus proche voisin (KNN)

# %%
#Define a subset of the dataset
df_knn = df_dataset.filter(['housing_median_age','total_rooms','total_bedrooms','population','households','median_income','median_house_value'], axis=1).copy()

# %%
# Define scaler to set values between 0 and 1

scaler = MinMaxScaler(feature_range=(0, 1))
df_knn = pd.DataFrame(scaler.fit_transform(df_knn), columns = df_knn.columns)

# %% [markdown]
# j'ai filtré les données et j'utilise MinMaxScalerscikit-learn pour normaliser mes données numériques entre 0 et 1.
#
# Étant donné que KNNImputer est un algorithme basé sur la distance, la mise à l'échelle est une étape importante dans le pipeline.

# %%
# Define KNN imputer and fill missing values
knn_imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
df_knn_imputed = pd.DataFrame(knn_imputer.fit_transform(df_knn), columns=df_knn.columns)

# %%
fig = plt.Figure()
null_values = df_dataset['total_bedrooms'].isnull() 
fig = df_knn_imputed.plot(x='total_rooms', y='total_bedrooms', kind='scatter', c=null_values, cmap='winter', title='KNN Imputation', colorbar=False)

# %% [markdown]
# #### Imputation multivariée par équation chaînée — MICE

# %%
# Imputing with MICE
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn import linear_model

df_mice = df_dataset.filter(['housing_median_age','total_rooms','total_bedrooms','population','households','median_income','median_house_value'], axis=1).copy()

# Define MICE Imputer and fill missing values
mice_imputer = IterativeImputer(estimator=linear_model.BayesianRidge(), n_nearest_features=None, imputation_order='ascending')

df_mice_imputed = pd.DataFrame(mice_imputer.fit_transform(df_mice), columns=df_mice.columns)

# %%
fig = plt.Figure()
null_values = df_dataset['total_bedrooms'].isnull() 
fig = df_mice_imputed.plot(x='total_rooms', y='total_bedrooms', kind='scatter', c=null_values, cmap='winter', title='MICE Imputation', colorbar=False)

# %% [markdown]
# ### Conclusion et choix pour l'imputation

# %% [markdown]
# Les techniques d'impoutation plus avancées, K-Nearest Neighbor Imputation (KNN) et Multivariate Imputation by Chained Equations (MICE) qui utilisent l'apprentissage automatique pour remplir les valeurs manquantes sont plus adaptés.
#
# Je choisi d'imputer les valeurs manquantes avec la méthode KNN qui consiste à les prédire.
#
# L'imputation par le plus proche voisin est la plus efficace pour mes valeurs manquantes.

# %%
# replace missing values on total_bedrooms with KNN
knn_imputer = KNNImputer(n_neighbors=4, weights="uniform")
df_dataset['total_bedrooms'] = knn_imputer.fit_transform(df_dataset[['total_bedrooms']])

# %% [markdown]
# ## Dataviz

# %%
sns.set(style="darkgrid",rc={'figure.figsize':(8,6)}, palette = "deep")
nouveau= sns.scatterplot(y="longitude", x="latitude", data=dataset, hue=dataset['ocean_proximity'], size =dataset['median_house_value'] )
nouveau.legend(bbox_to_anchor=(1, 1.1), loc='upper left')

# %%
data_median = dataset.groupby('ocean_proximity').count()

# %%
d= data_median['median_house_value'].value_counts()

# %%
data_proxi = pd.DataFrame(data_median)
data_proxi1 = data_proxi['median_house_value'].sort_values(ascending = False)
data_proxi2 = pd.DataFrame(data_proxi1)
data_proxi2
# Out:
#                  median_house_value
# ocean_proximity
# <1H OCEAN                      7312
# INLAND                         5235
# NEAR OCEAN                     2140
# NEAR BAY                       1821
# ISLAND                            4

# %%
data_proxi2.plot.pie(y='median_house_value',figsize=(8, 8),
                                explode = [0.1, 0.1,0.2, 0.2, 0.2],
                                labels=['<1H OCEAN','INLAND','NEAR OCEAN','NEAR BAY','ISLAND'],
                                autopct = '%1.1f%%',
                                pctdistance = 0.1, labeldistance = 0.7)

plt.title('Répartition ocean proximity', 
  loc='center', 
  fontsize=22)
plt.show()

# %%
sns.displot(data=dataset, x=dataset["median_house_value"], hue="ocean_proximity", kde=True)

# %%
data_df= dataset.drop(['latitude','longitude'], axis=1)

# %%
sns.pairplot(data_df, hue='ocean_proximity', markers=["o", "s", "D",'h', 'H'])

# %% [markdown]
# Je segmente les valeurs ocean_proximity en plusieurs dataset différent en vue d'une analyse eventuel si besoin

# %%
df_inland =   df_dataset[(df_dataset['ocean_proximity'] == 'INLAND')]
df_1h_ocean = df_dataset[(df_dataset['ocean_proximity'] == '<1H OCEAN')]
df_nearo =    df_dataset[(df_dataset['ocean_proximity'] == 'NEAR OCEAN')]
df_nearb =    df_dataset[(df_dataset['ocean_proximity'] == 'NEAR BAY')]
df_island =   df_dataset[(df_dataset['ocean_proximity'] == 'ISLAND')]

# %%
df_nearo
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7        -117.07     32.64                32.0       5135.0          1025.0
# 9        -122.47     37.50                18.0       2297.0           416.0
# 34       -117.12     32.58                34.0       2003.0           466.0
# 41       -122.55     37.59                31.0       1331.0           245.0
# 47       -117.20     32.77                30.0        156.0            45.0
# ...          ...       ...                 ...          ...             ...
# 16475    -117.09     32.75                30.0       1899.0           546.0
# 16488    -120.65     35.29                36.0       1940.0           315.0
# 16492    -117.11     32.78                16.0       2220.0           512.0
# 16506    -117.09     32.79                36.0       1529.0           266.0
# 16511    -124.13     40.80                31.0       2152.0           462.0
#
# ...

# %%
df_inland= df_inland.drop(['latitude','longitude'], axis=1)
df_inland.describe()
# Out:
#        housing_median_age   total_rooms  total_bedrooms    population  \
# count         5235.000000   5235.000000     5235.000000   5235.000000
# mean            24.175358   2734.174594      537.743339   1406.831519
# std             12.024423   2402.460303      449.373337   1187.462063
# min              1.000000      6.000000        2.000000      5.000000
# 25%             15.000000   1411.000000      285.000000    726.500000
# 50%             23.000000   2128.000000      427.000000   1135.000000
# 75%             33.000000   3249.000000      637.500000   1704.500000
# max             52.000000  39320.000000     6210.000000  16305.000000
#
#         households  median_income  median_house_value
# count  5235.000000    5235.000000         5235.000000
# mean    481.448138       3.194792       123981.856160
# std     396.330276       1.410523        68563.790283
# min       2.000000       0.499900        14999.000000
# 25%     256.000000       2.183800        77400.000000
# ...

# %% [markdown]
# ## Distribution

# %%
columns = ['housing_median_age','total_rooms','total_bedrooms',
               'population','households','median_income','median_house_value']

# %% [markdown]
# Je vais dans un premier temps drop me varaiables qualitives dans une nouveau dataset

# %%
df = df_dataset.drop(['ocean_proximity','latitude','longitude'], axis=1)
df
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                     6.0       1853.0           473.0      1397.0
# 1                     8.0       2032.0           349.0       862.0
# 2                    25.0        875.0           214.0       931.0
# 3                    31.0        622.0           229.0       597.0
# 4                    21.0       1922.0           373.0      1130.0
# ...                   ...          ...             ...         ...
# 16507                20.0       1465.0           278.0       745.0
# 16508                49.0       2365.0           504.0      1131.0
# 16509                19.0       2531.0           461.0      1206.0
# 16510                39.0       2776.0           840.0      2546.0
# 16511                31.0       2152.0           462.0      1259.0
#
#        households  median_income  median_house_value
# 0           417.0         1.4817             72000.0
# 1           340.0         6.9133            274100.0
# ...

# %%
#individuel plot
df.plot(kind='box', subplots=True, layout=(3, 5), figsize=(12, 12));

# %% [markdown]
# Il y a beaucoup de valeurs aberrantes dans l'ensemble de données.
#
# Mais, si nous vérifions le fichier de description des données , nous voyons qu'en réalité, certaines variables numériques sont
#
# Ainsi, certains de ces points de données qui semblent être des valeurs aberrantes sont, en fait, des données catégorielles avec un seul exemple d'une certaine catégorie.
#
# Gardons ces valeurs aberrantes.

# %%
df
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                     6.0       1853.0           473.0      1397.0
# 1                     8.0       2032.0           349.0       862.0
# 2                    25.0        875.0           214.0       931.0
# 3                    31.0        622.0           229.0       597.0
# 4                    21.0       1922.0           373.0      1130.0
# ...                   ...          ...             ...         ...
# 16507                20.0       1465.0           278.0       745.0
# 16508                49.0       2365.0           504.0      1131.0
# 16509                19.0       2531.0           461.0      1206.0
# 16510                39.0       2776.0           840.0      2546.0
# 16511                31.0       2152.0           462.0      1259.0
#
#        households  median_income  median_house_value
# 0           417.0         1.4817             72000.0
# 1           340.0         6.9133            274100.0
# ...

# %%
def var_hist(var, i):
    subset = df[var]
    n_dataset = len(df)
    xbar = np.mean(subset) # Moyenne
    sprime = np.std(subset, ddof=1) # Ecart-type
    sprime2 = np.var(subset, ddof=1) #Variance non biaisée
    ax = fig.add_subplot(i)
    ax.hist(subset, density=True)
    ax.axvline(xbar, color='r', linewidth=2, label="Moyenne empirique")
    bins = np.arange(subset.min(),subset.max(),0.05)
    y = norm.pdf(bins, xbar, sprime)
    ax.plot(bins, y, '--', label="Densité normale")
    ax.legend()
    ax.set_xlabel(var, fontsize=12)
    ax.set_ylabel('Densité', fontsize=12)
    ax.set_title('Distribution de '+str(var), fontsize=18)


liste_var = ['housing_median_age','total_rooms','total_bedrooms',
               'population','median_house_value','median_income']

fig = plt.figure(figsize=(20,30),constrained_layout=False)
i = 321
for var in liste_var :
    var_hist(var, i)
    i+=1
plt.show()

# %% [markdown]
# Remarques sur les variables :
#
# People : population - households : Distribution asymétriques très similaires
#
# Appartements : total rooms/bedrooms : Distribution asymétriques très similaires
#
# Comme on pouvait facilement l'imaginer Median_income et housing_median_age ont une distribution normal.

# %% [markdown]
# ### Scaling

# %%
col = np.array(df_dataset.drop(['ocean_proximity','latitude','longitude'], axis=1).columns)

# %%
# pip install mlxtend

# %%
for i in col :
# generate 1000 data points randomly drawn from an exponential distribution
    original_data =df_dataset[i]

# mix-max scale the data between 0 and 1
    scaled_data = minmax_scaling(original_data, columns=[0])

    # plot both together to compare
    fig, ax = plt.subplots(1, 2, figsize=(15, 3))
    sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
    ax[0].set_title("Original Data")
    sns.histplot(scaled_data, ax=ax[1], kde=True, legend=False)
    ax[1].set_title("Scaled data")
    plt.show()

# %% [markdown]
# ### Normalize

# %%
for i in col :
# generate 1000 data points randomly drawn from an exponential distribution
    original_data = df_dataset[i]

    # normalize the exponential data with boxcox
    normalized_data = stats.boxcox(original_data)

    # plot both together to compare
    fig, ax=plt.subplots(1, 2, figsize=(15, 3))
    sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
    ax[0].set_title("Original Data")
    sns.histplot(normalized_data[0], ax=ax[1], kde=True, legend=False)
    ax[1].set_title("Normalized data")
    plt.show()

# %%
liste_var = df
for var in liste_var :
    print(var,":",scs.ks_2samp(df_dataset[var],list(np.random.normal(np.mean(df_dataset[var]), np.std(df_dataset[var]), 1000))))
# Out:
# housing_median_age : KstestResult(statistic=0.06088275193798448, pvalue=0.0017599722363201165)
# total_rooms : KstestResult(statistic=0.18233866279069766, pvalue=6.563393154985227e-28)
# total_bedrooms : KstestResult(statistic=0.15362742248062022, pvalue=6.710383979928959e-20)
# population : KstestResult(statistic=0.14672771317829447, pvalue=3.492564264730031e-18)
# households : KstestResult(statistic=0.15293653100775195, pvalue=1.0051692997305086e-19)
# median_income : KstestResult(statistic=0.08685562015503878, pvalue=1.224151639624464e-06)
# median_house_value : KstestResult(statistic=0.099859011627907, pvalue=1.2247717056038637e-08)

# %% [markdown]
# Grâce au test de Kolmogorov-Smirnov réalisé ci-dessus, les Pvalues ne permettent pas de rejetter l'hypothèse gaussienne sur les variables suivantes (au niveau de test 5%) :
#
#  housing_median_age  , total_rooms , total_bedrooms, population , households , median_income , median_house_value .

# %% [markdown]
# ### Visualisation transformation du dataset

# %%
df
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                     6.0       1853.0           473.0      1397.0
# 1                     8.0       2032.0           349.0       862.0
# 2                    25.0        875.0           214.0       931.0
# 3                    31.0        622.0           229.0       597.0
# 4                    21.0       1922.0           373.0      1130.0
# ...                   ...          ...             ...         ...
# 16507                20.0       1465.0           278.0       745.0
# 16508                49.0       2365.0           504.0      1131.0
# 16509                19.0       2531.0           461.0      1206.0
# 16510                39.0       2776.0           840.0      2546.0
# 16511                31.0       2152.0           462.0      1259.0
#
#        households  median_income  median_house_value
# 0           417.0         1.4817             72000.0
# 1           340.0         6.9133            274100.0
# ...

# %%
dataset_minmax = MinMaxScaler().fit_transform(df)
dataset_minmax = pd.DataFrame(dataset_minmax, columns=['housing_median_age','total_rooms','total_bedrooms', 'population', 'households', 'median_income','median_house_value']) 
dataset_minmax
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                0.098039     0.046981        0.073103    0.039071
# 1                0.137255     0.051534        0.053857    0.024076
# 2                0.470588     0.022104        0.032904    0.026010
# 3                0.588235     0.015669        0.035232    0.016648
# 4                0.392157     0.048736        0.057582    0.031587
# ...                   ...          ...             ...         ...
# 16507            0.372549     0.037111        0.042837    0.020797
# 16508            0.941176     0.060004        0.077914    0.031615
# 16509            0.352941     0.064226        0.071240    0.033717
# 16510            0.745098     0.070458        0.130064    0.071274
# 16511            0.588235     0.054586        0.071395    0.035203
#
#        households  median_income  median_house_value
# 0        0.068257       0.067709            0.117527
# 1        0.055592       0.442297            0.534227
# ...

# %%
dataset_stdscl = StandardScaler().fit_transform(df)
dataset_stdscl = pd.DataFrame(dataset_stdscl, columns=['housing_median_age','total_rooms','total_bedrooms', 'population', 'households', 'median_income','median_house_value']) 
dataset_stdscl
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0               -1.795939    -0.357368       -0.156812   -0.032827
# 1               -1.637178    -0.276515       -0.450010   -0.494784
# 2               -0.287715    -0.799127       -0.769218   -0.435204
# 3                0.188566    -0.913406       -0.733750   -0.723603
# 4               -0.605236    -0.326201       -0.393262   -0.263373
# ...                   ...          ...             ...         ...
# 16507           -0.684616    -0.532626       -0.617890   -0.595810
# 16508            1.617410    -0.126100       -0.083513   -0.262510
# 16509           -0.763996    -0.051119       -0.185186   -0.197750
# 16510            0.823608     0.059547        0.710959    0.959301
# 16511            0.188566    -0.222311       -0.182822   -0.151986
#
#        households  median_income  median_house_value
# 0       -0.218173      -1.258403           -1.167387
# 1       -0.417841       1.610623            0.586611
# ...

# %%
dataset_robust = RobustScaler().fit_transform(df)
dataset_robust = pd.DataFrame(dataset_robust, columns=['housing_median_age','total_rooms','total_bedrooms', 'population', 'households', 'median_income','median_house_value']) 
dataset_robust
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0               -1.210526    -0.153981        0.100865    0.241053
# 1               -1.105263    -0.049180       -0.256484   -0.322105
# 2               -0.210526    -0.726581       -0.645533   -0.249474
# 3                0.105263    -0.874707       -0.602305   -0.601053
# 4               -0.421053    -0.113583       -0.187320   -0.040000
# ...                   ...          ...             ...         ...
# 16507           -0.473684    -0.381148       -0.461095   -0.445263
# 16508            1.052632     0.145785        0.190202   -0.038947
# 16509           -0.526316     0.242974        0.066282    0.040000
# 16510            0.526316     0.386417        1.158501    1.450526
# 16511            0.105263     0.021077        0.069164    0.095789
#
#        households  median_income  median_house_value
# 0        0.021472      -0.944201           -0.739490
# 1       -0.214724       1.558005            0.653343
# ...

# %%
# plt.scatter(df['median_house_value'],dataset_minmax['total_rooms'], alpha= 0.5, label='original' )
plt.scatter(dataset_stdscl['median_house_value'],dataset_stdscl['total_rooms'], alpha= 0.5, label='standart' )
plt.scatter(dataset_robust['median_house_value'],dataset_robust['total_rooms'], alpha= 0.5, label='robust' )
plt.scatter(dataset_minmax['median_house_value'],dataset_minmax['total_rooms'], alpha= 0.5, label='minmax' )
plt.legend()
plt.show()

# %% [markdown]
# Le minmax est trop sensible au outliers

# %% [markdown]
# ## Corrélation

# %%
fig, ax = plt.subplots(figsize=(9,6))   
sns.heatmap(df.corr(),cmap='Blues',annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# On observe que les variables total_rooms , total_dedrooms , population, households sont fortement corrélées entre elles positivement
#
# On observe également que median_house_value et median_income sont aussi corrélées entre elles (corrélation positive)
#
# J'analyserais plus fortement ses correlations et ma selection de features dans mon inférence.

# %% [markdown]
# ## Encoding

# %% [markdown]
# Je decide d'encoder ma variable qualitative.
#
# Je pourrais faire un encodage ordinal, mais quelle serait la valeur la plus importante entre Near Bay et near ocean par exemple.
#
# Je préfere faire un encodage one hot je pense que c'est plus approprier, de plus je n ai pas beaucoup de catégorie.
#
# Je garde quand meme en tete la possibilité d essayer un encodage ordinale pour une itérartion et/ou l'eventuel amélioration de mon model.

# %%
# encoding ocean_proximity
df_encod = pd.get_dummies(df_dataset, columns=['ocean_proximity'], prefix=["location"])
df_encod
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.84     36.77                 6.0       1853.0           473.0
# 1        -117.80     33.68                 8.0       2032.0           349.0
# 2        -120.19     36.60                25.0        875.0           214.0
# 3        -118.32     34.10                31.0        622.0           229.0
# 4        -121.23     37.79                21.0       1922.0           373.0
# ...          ...       ...                 ...          ...             ...
# 16507    -121.90     39.59                20.0       1465.0           278.0
# 16508    -122.25     38.11                49.0       2365.0           504.0
# 16509    -121.22     38.92                19.0       2531.0           461.0
# 16510    -118.14     34.16                39.0       2776.0           840.0
# 16511    -124.13     40.80                31.0       2152.0           462.0
#
# ...

# %% [markdown]
# ## Vérification de la variable cible

# %%
df['median_house_value'].describe()
# Out:
# count     16512.000000
# mean     206509.251453
# std      115225.957661
# min       14999.000000
# 25%      119400.000000
# 50%      179300.000000
# 75%      264500.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### Observation Outliers

# %%
# max & min value on median_house_value
print(df['median_house_value'].max())
print(df['median_house_value'].min())
# Out:
# 500001.0
# 14999.0

# %%
# boxplot
sns.boxplot(df['median_house_value'])
plt.show()

# %%
outliers = df_encod.loc[df_encod['median_house_value'] >= 430000]
outliers.describe()
# Out:
#          longitude     latitude  housing_median_age   total_rooms  \
# count  1154.000000  1154.000000         1154.000000   1154.000000
# mean   -119.722556    35.262634           33.578856   2987.989601
# std       1.966542     1.800526           13.002679   2206.755923
# min    -122.710000    32.630000            2.000000     20.000000
# 25%    -122.120000    33.970000           25.000000   1683.250000
# 50%    -118.470000    34.130000           34.000000   2492.000000
# 75%    -118.300000    37.430000           44.000000   3561.750000
# max    -116.430000    38.580000           52.000000  28258.000000
#
#        total_bedrooms    population   households  median_income  \
# count     1154.000000   1154.000000  1154.000000    1154.000000
# mean       515.296530   1163.854419   480.212305       7.158808
# std        370.003488    863.729815   339.390289       3.046155
# min          4.000000     13.000000     4.000000       0.499900
# ...

# %%
df_encod_sans_outliers = df_encod.loc[df_encod['median_house_value']< 430000]
df_encod_sans_outliers
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.84     36.77                 6.0       1853.0           473.0
# 1        -117.80     33.68                 8.0       2032.0           349.0
# 2        -120.19     36.60                25.0        875.0           214.0
# 3        -118.32     34.10                31.0        622.0           229.0
# 4        -121.23     37.79                21.0       1922.0           373.0
# ...          ...       ...                 ...          ...             ...
# 16507    -121.90     39.59                20.0       1465.0           278.0
# 16508    -122.25     38.11                49.0       2365.0           504.0
# 16509    -121.22     38.92                19.0       2531.0           461.0
# 16510    -118.14     34.16                39.0       2776.0           840.0
# 16511    -124.13     40.80                31.0       2152.0           462.0
#
# ...

# %%
sns.boxplot(df_encod_sans_outliers['median_house_value'])
plt.show()

# %% [markdown]
# ## Export CSV

# %% [markdown]
# ### Dataframe avec imputation Knn

# %%
# df_dataset.to_csv('DATA/df_dataset.csv')

# %% [markdown]
# ### Dataframe encoder et avec imputation Knn

# %%
# df_encod.to_csv('DATA/df_encod.csv')

# %% [markdown]
# ### Dataframe encoder et avec imputation Knn sans outliers

# %%
# df_encod_sans_outliers.to_csv('DATA/df_encod_sans_outliers.csv')
